# %% [markdown]
# # How to clean data
# The techniques used for data cleaning may vary according to the types of data but we can follow these basic steps to map out a framework for cleaning data

# %% [markdown]
# ### Step 1: Remove duplicate or irrelevant observations
# Remove unwanted observations from the dataset, including duplicate observation and irrelevant observations. Duplicate observations will happen most often during data collection. For example when we collect data from multiple sources. This process make the analysis more efficient and minimize the distraction from the main target.

# %% [markdown]
# ### Step 2: Fix structural errors

# %% [markdown]
# Structure errors appear when we measure or transfer data and notice strange naming conventions, typos or incorrect capitalization. These inconsistencies can cause mislabeled data like N/A for example.

# %% [markdown]
# ### Step 3: Filter unwanted outliers

# %% [markdown]
# This step is needed to determine the validity of the outliers. If an outlier proves to be irrelevant for analysis or is a mistake, consider removing it. Remember: just because an outlier exists, does not mean it is incorrect.

# %% [markdown]
# ### Step 4: Handle missing data

# %% [markdown]
# Many algoritms will not accept missing data. There are several ways to handle missing data:
# - As a first option, we can drop observations with missing data, but doing this will drop or lose information.
# - As a second option, we can input missing values based on other observations.
# - As a third option, we can alter the way the data is used to effectively navigate null values.

# %% [markdown]
# ### Step 5: Validate and QA

# %% [markdown]
# At the end of the data cleaning process, you should be able to answer these questions as a part of basic validation:
# - Does the data make sense?
# - Does the data follow the appropriate rules for its field?
# - Does it prove or disprove your working theory, or bring any insight to light?
# - Can you find trends in the data to help you form your next theory?
# - If not, is that because of a data quality issue?
